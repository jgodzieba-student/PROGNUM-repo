# %% [markdown]
# Answers for Week 1
#
# * Name: Kacper Godzieba
# * Username: jgodzieba
# * Student s-number: S6392296
# * Group (AS1, etc.): AS5

# %% [markdown]
# x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![Gambus the great.jpg](attachment:890766fc-8525-4709-b5cf-feddf333aa02.jpg)

# %%
fact=6
fact*=5
fact*=4
fact*=3
fact*=2
print(fact)
# Out:
# 720

# %%
from scipy.constants import h
E = h * 2.42*10**28
print(E)
# Out:
# 1.6035089763e-05

# %%
G = 6.67*10**(-11)
m = 7.342*10**(22)
M = 5.9722*10**(24)
r = 385000600
F = (G * m * M)/(r**2)
print(F)
# Out:
# 1.973112030558486e+20

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %% [markdown]
# It prints them both in one line one after the other

# %% [markdown]
# ![Zrzut ekranu 2026-02-12 132216.png](attachment:ab96321a-4e42-440e-af32-db12be09acf7.png)

# %% [markdown]
# 1.15
#
# 1. It will print the absolute path of the download directory.
# 2. . is the currect directory .. is the parent directory
#
# 1.16 --> cd ~/name
#
# 1.19
#
# wild card * --> if placed after a name such as name* it will signify all files starting with name no matter the ending
#
# 1. list of files with with both nr between 0-9 and the letter c or o after .
# 2. it looks for a group with a thing in the brackets
# 3. Instead of c or o, its specificaly .co
